# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import re
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 4000)

# %%
#import patial data - 50K rows
accres = pd.read_csv('../Data/accre-jobs-2020-updated-columns.txt', nrows=50000)
# Out:
# C:\Users\alvin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (13,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
accres.head()
# Out:
#       JOBID  ACCOUNT      USER    REQMEM    USEDMEM      REQTIME     USEDTIME  \
# 0  15925210  treviso  arabella  122880Mn  65973.49M  13-18:00:00  13-18:00:28
# 1  15861126  treviso  arabella  122880Mn  67181.12M  13-18:00:00  12-14:50:56
# 2  15861125  treviso  arabella  122880Mn  69111.86M  13-18:00:00  13-18:00:20
# 3  16251645  treviso  arabella  122880Mn  65317.33M  13-18:00:00  12-03:50:32
# 4  16251646  treviso  arabella  122880Mn  65876.11M  13-18:00:00  13-18:00:03
#
#    NODES  CPUS   PARTITION EXITCODE      STATE NODELIST NODELIST1 NODELIST2  \
# 0      1    24  production      0:0  COMPLETED   cn1531       NaN       NaN
# 1      1    24  production      0:0  COMPLETED   cn1441       NaN       NaN
# 2      1    24  production      0:0  COMPLETED   cn1464       NaN       NaN
# 3      1    24  production      0:0  COMPLETED   cn1473       NaN       NaN
# 4      1    24  production      0:0  COMPLETED   cn1440       NaN       NaN
#
# ...

# %%
#filter on production only
accres_prod = accres.loc[accres['PARTITION'] == 'production']

# %%
accres_prod
# Out:
#             JOBID      ACCOUNT      USER    REQMEM    USEDMEM      REQTIME  \
# 0        15925210      treviso  arabella  122880Mn  65973.49M  13-18:00:00
# 1        15861126      treviso  arabella  122880Mn  67181.12M  13-18:00:00
# 2        15861125      treviso  arabella  122880Mn  69111.86M  13-18:00:00
# 3        16251645      treviso  arabella  122880Mn  65317.33M  13-18:00:00
# 4        16251646      treviso  arabella  122880Mn  65876.11M  13-18:00:00
# ...           ...          ...       ...       ...        ...          ...
# 49995  17138476_2  horseradish    jimena    7168Mn   5072.90M     01:30:00
# 49996  17138476_3  horseradish    jimena    7168Mn   4334.61M     01:30:00
# 49997  17138476_4  horseradish    jimena    7168Mn   4446.14M     01:30:00
# 49998  17138476_5  horseradish    jimena    7168Mn   3821.07M     01:30:00
# 49999  17138476_6  horseradish    jimena    7168Mn   3637.83M     01:30:00
#
# ...

# %%
# to slice off first to characters in nodelist column 
accres_prod['NODELIST'] = accres_prod['NODELIST'].str[2:]
accres_prod
# Out:
# <ipython-input-6-b85fe6049e64>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accres_prod['NODELIST'] = accres_prod['NODELIST'].str[2:]
#             JOBID      ACCOUNT      USER    REQMEM    USEDMEM      REQTIME  \
# 0        15925210      treviso  arabella  122880Mn  65973.49M  13-18:00:00
# 1        15861126      treviso  arabella  122880Mn  67181.12M  13-18:00:00
# 2        15861125      treviso  arabella  122880Mn  69111.86M  13-18:00:00
# 3        16251645      treviso  arabella  122880Mn  65317.33M  13-18:00:00
# 4        16251646      treviso  arabella  122880Mn  65876.11M  13-18:00:00
# ...           ...          ...       ...       ...        ...          ...
# ...

# %%
#list columns to prepare droping non useful columns
accres.columns
# Out:
# Index(['JOBID', 'ACCOUNT', 'USER', 'REQMEM', 'USEDMEM', 'REQTIME', 'USEDTIME',
#        'NODES', 'CPUS', 'PARTITION', 'EXITCODE', 'STATE', 'NODELIST',
#        'NODELIST1', 'NODELIST2', 'NODELIST3', 'NODELIST4', 'NODELIST5',
#        'NODELIST6', 'NODELIST7', 'NODELIST8', 'NODELIST9', 'NODELIST10',
#        'NODELIST11', 'NODELIST12', 'NODELIST13', 'NODELIST14', 'NODELIST15',
#        'NODELIST16', 'NODELIST17', 'NODELIST18', 'NODELIST19', 'NODELIST20',
#        'NODELIST21', 'NODELIST22', 'NODELIST23', 'NODELIST24', 'NODELIST25',
#        'NODELIST26', 'NODELIST27', 'NODELIST28', 'NODELIST29', 'NODELIST30',
#        'NODELIST31', 'NODELIST32', 'NODELIST33', 'NODELIST34', 'NODELIST35',
#        'NODELIST36', 'NODELIST37', 'NODELIST38', 'NODELIST39', 'NODELIST40',
#        'NODELIST41', 'NODELIST42', 'NODELIST43', 'NODELIST44', 'NODELIST45',
#        'NODELIST46', 'NODELIST47', 'NODELIST48', 'NODELIST49', 'NODELIST50',
# ...

# %%
# drop off all columns except jobid and nodes
accres_prod.drop(accres.columns.difference(['JOBID', 'NODELIST',
       'NODELIST1', 'NODELIST2', 'NODELIST3', 'NODELIST4', 'NODELIST5',
       'NODELIST6', 'NODELIST7', 'NODELIST8', 'NODELIST9', 'NODELIST10',
       'NODELIST11', 'NODELIST12', 'NODELIST13', 'NODELIST14', 'NODELIST15',
       'NODELIST16', 'NODELIST17', 'NODELIST18', 'NODELIST19', 'NODELIST20',
       'NODELIST21', 'NODELIST22', 'NODELIST23', 'NODELIST24', 'NODELIST25',
       'NODELIST26', 'NODELIST27', 'NODELIST28', 'NODELIST29', 'NODELIST30',
       'NODELIST31', 'NODELIST32', 'NODELIST33', 'NODELIST34', 'NODELIST35',
       'NODELIST36', 'NODELIST37', 'NODELIST38', 'NODELIST39', 'NODELIST40',
       'NODELIST41', 'NODELIST42', 'NODELIST43', 'NODELIST44', 'NODELIST45',
       'NODELIST46', 'NODELIST47', 'NODELIST48', 'NODELIST49', 'NODELIST50',
       'NODELIST51', 'NODELIST52', 'NODELIST53', 'NODELIST54', 'NODELIST55',
       'NODELIST56', 'NODELIST57', 'NODELIST58', 'NODELIST59', 'NODELIST60',
       'NODELIST61', 'NODELIST62', 'NODELIST63', 'NODELIST64', 'NODELIST65',
       'NODELIST66', 'NODELIST67', 'NODELIST68', 'NODELIST69', 'NODELIST70',
       'NODELIST71', 'NODELIST72', 'NODELIST73', 'NODELIST74', 'NODELIST75',
       'NODELIST76', 'NODELIST77', 'NODELIST78', 'NODELIST79', 'NODELIST80',
       'NODELIST81', 'NODELIST82', 'NODELIST83', 'NODELIST84', 'NODELIST85',
       'NODELIST86', 'NODELIST87']), 1, inplace=True)
# Out:
# C:\Users\alvin\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
accres_prod
# Out:
#             JOBID NODELIST NODELIST1 NODELIST2 NODELIST3  NODELIST4  \
# 0        15925210     1531       NaN       NaN       NaN        NaN
# 1        15861126     1441       NaN       NaN       NaN        NaN
# 2        15861125     1464       NaN       NaN       NaN        NaN
# 3        16251645     1473       NaN       NaN       NaN        NaN
# 4        16251646     1440       NaN       NaN       NaN        NaN
# ...           ...      ...       ...       ...       ...        ...
# 49995  17138476_2     1282       NaN       NaN       NaN        NaN
# 49996  17138476_3     1370       NaN       NaN       NaN        NaN
# 49997  17138476_4     1387       NaN       NaN       NaN        NaN
# 49998  17138476_5     1325       NaN       NaN       NaN        NaN
# 49999  17138476_6     1370       NaN       NaN       NaN        NaN
#
#        NODELIST5  NODELIST6  NODELIST7  NODELIST8  NODELIST9  NODELIST10  \
# 0            NaN        NaN        NaN        NaN        NaN         NaN
# ...

# %%
#convert jobid to be the index
accres_reindex = accres_prod.set_index('JOBID')
accres_reindex
# Out:
#            NODELIST NODELIST1 NODELIST2 NODELIST3  NODELIST4  NODELIST5  \
# JOBID
# 15925210       1531       NaN       NaN       NaN        NaN        NaN
# 15861126       1441       NaN       NaN       NaN        NaN        NaN
# 15861125       1464       NaN       NaN       NaN        NaN        NaN
# 16251645       1473       NaN       NaN       NaN        NaN        NaN
# 16251646       1440       NaN       NaN       NaN        NaN        NaN
# ...             ...       ...       ...       ...        ...        ...
# 17138476_2     1282       NaN       NaN       NaN        NaN        NaN
# 17138476_3     1370       NaN       NaN       NaN        NaN        NaN
# 17138476_4     1387       NaN       NaN       NaN        NaN        NaN
# 17138476_5     1325       NaN       NaN       NaN        NaN        NaN
# 17138476_6     1370       NaN       NaN       NaN        NaN        NaN
#
#             NODELIST6  NODELIST7  NODELIST8  NODELIST9  NODELIST10  \
# JOBID
# ...

# %%
# Transposes data and leaves out NaN values
accres_stacked = accres_reindex.stack()

# %%
# reset index and make back into dataframe
accres_stacked = accres_stacked.to_frame().reset_index()
accres_stacked
# Out:
#             JOBID   level_1     0
# 0        15925210  NODELIST  1531
# 1        15861126  NODELIST  1441
# 2        15861125  NODELIST  1464
# 3        16251645  NODELIST  1473
# 4        16251646  NODELIST  1440
# ...           ...       ...   ...
# 40108  17138476_2  NODELIST  1282
# 40109  17138476_3  NODELIST  1370
# 40110  17138476_4  NODELIST  1387
# 40111  17138476_5  NODELIST  1325
# 40112  17138476_6  NODELIST  1370
#
# [40113 rows x 3 columns]

# %%
#splits data from column 0 if there is a hyphen to another column
accres_stacked['2']=[x.split('-') for x in accres_stacked[0]]

# %%
accres_stacked
# Out:
#             JOBID   level_1     0       2
# 0        15925210  NODELIST  1531  [1531]
# 1        15861126  NODELIST  1441  [1441]
# 2        15861125  NODELIST  1464  [1464]
# 3        16251645  NODELIST  1473  [1473]
# 4        16251646  NODELIST  1440  [1440]
# ...           ...       ...   ...     ...
# 40108  17138476_2  NODELIST  1282  [1282]
# 40109  17138476_3  NODELIST  1370  [1370]
# 40110  17138476_4  NODELIST  1387  [1387]
# 40111  17138476_5  NODELIST  1325  [1325]
# 40112  17138476_6  NODELIST  1370  [1370]
#
# [40113 rows x 4 columns]

# %%
# to grab first element of list and make new column
accres_stacked['S'] = accres_stacked['2'].map(lambda x: x[0])

# %%
# to assign a blank list
empty=[]

# %%
# to add the second variable in a list (node-range) to a running list (named empty)
# if there isn't a second variable in list it takes the first variable in the list
for i in accres_stacked['2']:
    try:
        a=i[1]
        empty.append(a)
    except:
        empty.append(i[0])

# %%
#this appends the empty list filled out from for loop to data frame as new column
accres_stacked['3'] = empty

# %%
accres_stacked
# Out:
#             JOBID   level_1     0       2     S     3
# 0        15925210  NODELIST  1531  [1531]  1531  1531
# 1        15861126  NODELIST  1441  [1441]  1441  1441
# 2        15861125  NODELIST  1464  [1464]  1464  1464
# 3        16251645  NODELIST  1473  [1473]  1473  1473
# 4        16251646  NODELIST  1440  [1440]  1440  1440
# ...           ...       ...   ...     ...   ...   ...
# 40108  17138476_2  NODELIST  1282  [1282]  1282  1282
# 40109  17138476_3  NODELIST  1370  [1370]  1370  1370
# 40110  17138476_4  NODELIST  1387  [1387]  1387  1387
# 40111  17138476_5  NODELIST  1325  [1325]  1325  1325
# 40112  17138476_6  NODELIST  1370  [1370]  1370  1370
#
# [40113 rows x 6 columns]

# %%
accres_stacked.columns
# Out:
# Index(['JOBID', 'level_1', 0, '2', 'S', '3'], dtype='object')

# %%
#Rename columns
accres_stacked.columns = ['JOBID', 'NODELIST','INTIALNODES', 'LIST','STARTNODE', 'ENDNODE']

# %%
# To Delete column
del accres_stacked['NODELIST']

# %%
accres_stacked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40113 entries, 0 to 40112
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JOBID        40113 non-null  object
#  1   INTIALNODES  40113 non-null  object
#  2   LIST         40113 non-null  object
#  3   STARTNODE    40113 non-null  object
#  4   ENDNODE      40113 non-null  object
# dtypes: object(5)
# memory usage: 1.5+ MB

# %%
accres_stacked
# Out:
#             JOBID INTIALNODES    LIST STARTNODE ENDNODE
# 0        15925210        1531  [1531]      1531    1531
# 1        15861126        1441  [1441]      1441    1441
# 2        15861125        1464  [1464]      1464    1464
# 3        16251645        1473  [1473]      1473    1473
# 4        16251646        1440  [1440]      1440    1440
# ...           ...         ...     ...       ...     ...
# 40108  17138476_2        1282  [1282]      1282    1282
# 40109  17138476_3        1370  [1370]      1370    1370
# 40110  17138476_4        1387  [1387]      1387    1387
# 40111  17138476_5        1325  [1325]      1325    1325
# 40112  17138476_6        1370  [1370]      1370    1370
#
# [40113 rows x 5 columns]

# %%
accres_stacked['STARTNODE'] = accres_stacked['STARTNODE'].str.replace("[", "") 
accres_stacked['STARTNODE'] = accres_stacked['STARTNODE'].str.replace("]", "")

# %%
accres_stacked['ENDNODE'] = accres_stacked['ENDNODE'].str.replace("[", "")
accres_stacked['ENDNODE'] = accres_stacked['ENDNODE'].str.replace("]", "")

# %%
accres_stacked.iloc[3423]
# Out:
# JOBID          17050901_90
# INTIALNODES          1134]
# LIST               [1134]]
# STARTNODE            1134]
# ENDNODE               1134
# Name: 3423, dtype: object

# %%
accres_stacked[['STARTNODE', 'ENDNODE']] = accres_stacked[['STARTNODE', 'ENDNODE']].apply(pd.to_numeric)

# %%
#Need help to turn numbers into integers to perform arithmetic operation
accres_stacked['Difference'] = accres_stacked['ENDNODE'] - accres_stacked['STARTNODE']
accres_stacked
# Out:
#             JOBID INTIALNODES    LIST  STARTNODE  ENDNODE  Difference
# 0        15925210        1531  [1531]       1531     1531           0
# 1        15861126        1441  [1441]       1441     1441           0
# 2        15861125        1464  [1464]       1464     1464           0
# 3        16251645        1473  [1473]       1473     1473           0
# 4        16251646        1440  [1440]       1440     1440           0
# ...           ...         ...     ...        ...      ...         ...
# 40108  17138476_2        1282  [1282]       1282     1282           0
# 40109  17138476_3        1370  [1370]       1370     1370           0
# 40110  17138476_4        1387  [1387]       1387     1387           0
# 40111  17138476_5        1325  [1325]       1325     1325           0
# 40112  17138476_6        1370  [1370]       1370     1370           0
#
# [40113 rows x 6 columns]

# %%
accres_stacked['Difference'].max()
# Out:
# 2

# %%
accres_stacked[accres_stacked.JOBID=='17126611']
# Out:
#           JOBID  INTIALNODES            LIST  STARTNODE  ENDNODE  Difference
# 19493  17126611  [1430-1432]  [[1430, 1432]]       1430     1432           2

# %%
# if difference column is > 1 then create new cell in another column with startnode + 1, 
#keep going until diff minus iterations equals 1

# %%
#Another stack or melt function to get nodes all in one column

# %%
while difference > 1:
         = STARTNODE + 1
        difference = difference - 1
        
    return

# %%
def Alvin_function(num):
    sum=0
    while num > 0:
        sum += num*num
        num = num- 1
    return sum

# %%
1530
1533
3

1531
1532

1

# %%
accres_stacked['Range_list'] = accres_stacked.apply(lambda x: list(range(x['STARTNODE'],x['ENDNODE']+1)), axis=1)

# %%
#accres_List[19493] 
accres_stacked
# Out:
#             JOBID INTIALNODES    LIST  STARTNODE  ENDNODE  Difference  \
# 0        15925210        1531  [1531]       1531     1531           0
# 1        15861126        1441  [1441]       1441     1441           0
# 2        15861125        1464  [1464]       1464     1464           0
# 3        16251645        1473  [1473]       1473     1473           0
# 4        16251646        1440  [1440]       1440     1440           0
# ...           ...         ...     ...        ...      ...         ...
# 40108  17138476_2        1282  [1282]       1282     1282           0
# 40109  17138476_3        1370  [1370]       1370     1370           0
# 40110  17138476_4        1387  [1387]       1387     1387           0
# 40111  17138476_5        1325  [1325]       1325     1325           0
# 40112  17138476_6        1370  [1370]       1370     1370           0
#
#       Range_list
# 0         [1531]
# 1         [1441]
# 2         [1464]
# 3         [1473]
# 4         [1440]
# ...

# %%
accres_stacked_List = pd.DataFrame(accres_stacked["Range_list"].to_list(), columns=['NODELIST1', 'NODELIST2','NODELIST3'])

# %%
accres_merged =  pd.merge(accres_stacked, accres_stacked_List, left_index=True, right_index=True)

# %%
accres_merged
# Out:
#             JOBID INTIALNODES    LIST  STARTNODE  ENDNODE  Difference  \
# 0        15925210        1531  [1531]       1531     1531           0
# 1        15861126        1441  [1441]       1441     1441           0
# 2        15861125        1464  [1464]       1464     1464           0
# 3        16251645        1473  [1473]       1473     1473           0
# 4        16251646        1440  [1440]       1440     1440           0
# ...           ...         ...     ...        ...      ...         ...
# 40108  17138476_2        1282  [1282]       1282     1282           0
# 40109  17138476_3        1370  [1370]       1370     1370           0
# 40110  17138476_4        1387  [1387]       1387     1387           0
# 40111  17138476_5        1325  [1325]       1325     1325           0
# 40112  17138476_6        1370  [1370]       1370     1370           0
#
#       Range_list  NODELIST1  NODELIST2  NODELIST3
# 0         [1531]       1531        NaN        NaN
# ...

# %%
accres_merged.columns
# Out:
# Index(['JOBID', 'INTIALNODES', 'LIST', 'STARTNODE', 'ENDNODE', 'Difference',
#        'Range_list', 'NODELIST1', 'NODELIST2', 'NODELIST3'],
#       dtype='object')

# %%
accres_merged.drop(['INTIALNODES', 'LIST', 'STARTNODE', 'ENDNODE', 'Difference','Range_list'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-477e3ad86e4a> in <module>
# ----> 1 accres_merged_prestack = accres_merged.drop(['INTIALNODES', 'LIST', 'STARTNODE', 'ENDNODE', 'Difference','Range_list'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
accres_merged
# Out:
#             JOBID  NODELIST1  NODELIST2  NODELIST3
# 0        15925210       1531        NaN        NaN
# 1        15861126       1441        NaN        NaN
# 2        15861125       1464        NaN        NaN
# 3        16251645       1473        NaN        NaN
# 4        16251646       1440        NaN        NaN
# ...           ...        ...        ...        ...
# 40108  17138476_2       1282        NaN        NaN
# 40109  17138476_3       1370        NaN        NaN
# 40110  17138476_4       1387        NaN        NaN
# 40111  17138476_5       1325        NaN        NaN
# 40112  17138476_6       1370        NaN        NaN
#
# [40113 rows x 4 columns]

# %%
accres_reindex1 = accres_merged.set_index('JOBID')

# %%
accres_nodes_clean = accres_reindex1.stack()

# %%
accres_nodes_clean = accres_nodes_clean.to_frame().reset_index()

# %%
accres_nodes_clean
# Out:
#             JOBID    level_1       0
# 0        15925210  NODELIST1  1531.0
# 1        15861126  NODELIST1  1441.0
# 2        15861125  NODELIST1  1464.0
# 3        16251645  NODELIST1  1473.0
# 4        16251646  NODELIST1  1440.0
# ...           ...        ...     ...
# 40198  17138476_2  NODELIST1  1282.0
# 40199  17138476_3  NODELIST1  1370.0
# 40200  17138476_4  NODELIST1  1387.0
# 40201  17138476_5  NODELIST1  1325.0
# 40202  17138476_6  NODELIST1  1370.0
#
# [40203 rows x 3 columns]

# %%
accres_nodes_clean.drop(['level_1'], axis=1, inplace=True)

# %%
accres_nodes_clean.columns = ['JOBID', 'NODES']

# %%
accres_nodes_clean
# Out:
#             JOBID   NODES
# 0        15925210  1531.0
# 1        15861126  1441.0
# 2        15861125  1464.0
# 3        16251645  1473.0
# 4        16251646  1440.0
# ...           ...     ...
# 40198  17138476_2  1282.0
# 40199  17138476_3  1370.0
# 40200  17138476_4  1387.0
# 40201  17138476_5  1325.0
# 40202  17138476_6  1370.0
#
# [40203 rows x 2 columns]

# %%
#Below is Matt P's Code for spliting out exit codes

# %%
#accre[['exitcode_user', 'exitcode_node']] = accre['exitcode'].str.split(':', expand=True).astype(int)
#skips exit code node into two columns

# %%
#accre_node_failure = accre.loc[accre['exitcode_node'] != 0]
# creates dataframe where there are only rows with a data failure
